# %% [markdown]
# 在教学过程中， 发现大多数人会遇到如下两类问题。
# ![学习的瓶颈](./picture/6-1.jpg)
# 我十分理解你的状态。就像当年我们在学校上学一样，老师讲的时候啥都会，老师一走啥也不会。前一天全记得，试卷一发心凉凉。
# 作为一个领路人，接下来，我要给大家传授一下江湖秘籍，帮助大家打通任督二脉。
# ## 知识点易忘
# 首先，来看第一个瓶颈：
# ![第一个瓶颈](./picture/6-2.jpg)
# 对于这一点，小K的态度就是“那就忘了吧”， 无所谓。
# 你会发现，之前小K教给大家一些内容，小K说你先记下来，什么时候用到再拿出来看看。编程的武林很开放，不会让你闭门造车。
# 因为，我们学习编程是为了获得一门技能，技能在于用，而不是死记硬背。
# 有的同学会说，我内容都记不住，我怎么用？
# 先走出一个误区。
# ![第一个瓶颈](./picture/6-3.jpg)
# 掌握知识是说知道这个知识点，用在哪儿？而记住知识只是知道内容，但不知道怎么用。
# Python整个江湖中有很多剑谱、武功秘籍，哪能全都记得住。 所以在刚踏入Python江湖时，先有个印象，遇到不明白的就去看看学习记录，然后再去运行代码。
# 就像张真人教无忌打太极一样，当无忌需要迎战玄冥二老时，张真人才教无忌太极。
# 就是临时抱佛脚。
# 那么，这种临时抱佛脚，得有佛脚可抱啊。那么佛脚去哪儿找呢？其实，简单得很，下面小K带大家看几个例子就明白了。
# ### 1.1 内容笔记
# ![第一个瓶颈](./picture/6-4.jpg)
# 内容笔记，就是你要做好自己的武功秘籍，将平时的知识点用法记录下来，形成自己的武功秘籍，它能够供你快速查阅，加深对知识的印象。
# 不管你用啥记，只要你能看懂就可以。
# 小K在刚刚学习编程的时候，会详细的把案例整理。
# 比如先看一下简单的“四则运算”。
# ![第一个瓶颈](./picture/6-5.jpg)
# 这张笔记，就是使用小案例来介绍四则运算的；并且用注释来解释上一行代码的意思；什么时候用到了，再回来翻一翻。
# 再来看看小K写的列表的笔记。
# ![第一个瓶颈](./picture/6-6.jpg)
# 依旧是代码与注释，注释对代码解释，包含实际运行结果。这样才能加深对知识的第一印象。
# 最后，再来看一下以“字典”知识为例的笔记，当然，笔记是给自己看的，记录哪些内容，看你自己对知识点的熟悉度。
# ![第一个瓶颈](./picture/6-7.jpg)
# 就像这样，随着你以后在Python江湖中的历练，你能够积累越来越多的【内容笔记】。
# 说完了【内容笔记】，接下来看看【总结笔记】。
# ### 1.2 总结笔记
# ![第一个瓶颈](./picture/6-8.jpg)
# 光有了笔记还不成，还需要理解笔记，进行总结，这样你在遇到问题时，才能想到所学的知识。
# 【总结笔记】在于“理解”， 所以要着重总结对笔记的理解。你看一下我对循环知识的理解笔记：
# ![第一个瓶颈](./picture/6-9.jpg)
# 可以看出，【内容笔记】解决“知识点是什么”的问题，而【总结笔记】更侧重“为什么用”以及“怎么用”。
# 再来看一个关于列表和字典的例子：
# ![第一个瓶颈](./picture/6-10.jpg)
# 总结笔记不是一次成型的，而是在你理解过程中循序渐进慢慢完成的。
# ### 1.3 知识管理
# ![第一个瓶颈](./picture/6-11.jpg)
# 其实，内容笔记和总结笔记是搭配使用的，就如同字典中的键与值。内容笔记就是键，总结笔记就是值。
# ![第一个瓶颈](./picture/6-12.jpg)
# 随着我们知识量越来越多，知识结构会更加完整，我们使用知识也会越来越顺。
# 如果你发现自己“知识点易忘”的话，不妨试一试小K所教的笔记法。
# 当然，你不要偷懒哦。
# ## 解题没思路
# ![第一个瓶颈](./picture/6-13.jpg)
# 接下来，我们来解决第二个瓶颈：解题没思路。也就是看到题目，思路被卡死了。
# ### 2.1如何解题
# 每个人都有每个人的解题思路，但是总结起来，可以分为这么几步：
# ![第一个瓶颈](./picture/6-14.jpg)
# 比如说，我们要使用Python打印出九九乘法表。
# 如何解决这个题目。
# 分析问题永远都是NO.1 思考这到底是个什么样的问题？
# ![第一个瓶颈](./picture/6-15.jpg)
# 题目要求我们打印九九乘法表，先看看九九乘法表是什么样子的？
# ![第一个瓶颈](./picture/6-16.jpg)
# 好了，现在已经明确问题了，也知道要做出什么样的效果？那就来思考一下解决这个问题需要什么知识？
# ![第一个瓶颈](./picture/6-17.jpg)
# 首先，打印内容，使用到print()函数。
# ```
# print('1 X 1 = 1')
# print('1 X 2 = 2  2 X 2 = 4')
# print('1 X 3 = 3  2 X 3 = 6  3 X 3 = 9')
# print('1 X 4 = 4  2 X 4 = 8  3 X 4 = 12  4 X 4 = 16')
# ```
# 你可以一行一行的打印，但是九九乘法表这么大， 你一行一行的打印到啥时候？
# 如果细心观察九九乘法表，你会发现，九九乘法表是有规律的，有重复内容的？
# 哪里有重复内容？你看九九乘法表只有数字在变，格式还是那个样子，都在重复。所以，用循环来解决。这就找到了问题的切入点。
# ![第一个瓶颈](./picture/6-18.jpg)
# 细细观察九九乘法表，你会发现一个规律：每一行的等式里，第二位数会递增，第一位数则会保持不变，并且在第几行就会有多少个等式。
# ![第一个瓶颈](./picture/6-19.jpg)
# 也就说每一行都是一个循环。那我们就把这个小循环先写出来。
# 江湖秘籍：永远从最简单的切入点入手，解决一部分，解决解决着，问题就迎刃而解了。
# ![第一个瓶颈](./picture/6-20.jpg)
# 完成这个小循环，用for循环还是while循环？
# 每一行打印的内容是有限的，也就是循环次数是确定的，用for循环啊。
# 是不是和我们猜的一样？
# 下面，使用for循环将九九乘法表中的前三行打印出来。
# 你自己试一下：【提示：先回去翻一翻笔记，看看内容，然后再来写；需要两个内容知识点：for循环，字符串格式化】

# %%
for i in range(1,2):
    print('%d X %d = %d' % (i, 1, i*1))
for i in range(1,3):
    print('%d X %d = %d' % (i,2,i*2))
for i in range(1,4):
    print('%d X %d = %d' % (i,3,i*3))
# Out:
# 1 X 1 = 1
# 1 X 2 = 2
# 2 X 2 = 4
# 1 X 3 = 3
# 2 X 3 = 6
# 3 X 3 = 9

# %% [markdown]
# 我们的每一个等式都换行了，但是我们要的是：
# ![乘法表](./picture/6-21.jpg)
# 需要解决这个问题，所以，我们需要回到第二步重新考虑问题。
# ![如何解题](./picture/6-22.jpg)
# 我们需要的是不让print()打印的时候换行。
# 怎么办？老师没有讲过啊。怎么办？在线急等。
# 找百度啊。去百度搜一搜怎么办。
# ![换行](./picture/6-23.jpg)
# 点进去，我们就能找到答案。【注：我们学习的内容是Python3.0语法】
# ![换行](./picture/6-24.jpg)
# 搜嘎，原来要想让print()不换行，末尾加end=’’就可以啊。
# 运行一下下面代码, 观察终端里的效果。

# %%
print('hi',end='')
print('Python')

print('hi',end='  ')
print('Python')

print('hi',end='!')
print('Python')
# Out:
# hiPython
# hi  Python
# hi!Python

# %% [markdown]
# ![如何解题](./picture/6-25.jpg)
# 那么我们的九九乘法表，就可以改成：

# %%
for i in range(1,2):
    print('%d X %d = %d' % (i, 1, i*1), end='  ')
for i in range(1,3):
    print('%d X %d = %d' % (i,2,i*2), end=' ')
for i in range(1,4):
    print('%d X %d = %d' % (i,3,i*3), end=' ')
# Out:
# 1 X 1 = 1  1 X 2 = 2 2 X 2 = 4 1 X 3 = 3 2 X 3 = 6 3 X 3 = 9

# %% [markdown]
# 运行一下，又都压缩到一行里去了。
# 别着急，小K告诉大家一个秘籍。
# 江湖秘籍：使用print(‘’)来控制换行。
# 运行一下下面代码，观察终端里的效果。

# %%
for i in range(1,2):
    print('%d X %d = %d' % (i, 1, i*1), end='  ')
print('')
for i in range(1,3):
    print('%d X %d = %d' % (i,2,i*2), end='  ')
print('')
for i in range(1,4):
    print('%d X %d = %d' % (i,3,i*3), end='  ')
# Out:
# 1 X 1 = 1
# 1 X 2 = 2  2 X 2 = 4
# 1 X 3 = 3  2 X 3 = 6  3 X 3 = 9

# %%
for i in range(1,10):
    for j in range(1,i+1):
        print( '%d X %d = %d' % (j,i,i*j),end = '  ' )
    print('  ')
# Out:
# 1 X 1 = 1
# 1 X 2 = 2  2 X 2 = 4
# 1 X 3 = 3  2 X 3 = 6  3 X 3 = 9
# 1 X 4 = 4  2 X 4 = 8  3 X 4 = 12  4 X 4 = 16
# 1 X 5 = 5  2 X 5 = 10  3 X 5 = 15  4 X 5 = 20  5 X 5 = 25
# 1 X 6 = 6  2 X 6 = 12  3 X 6 = 18  4 X 6 = 24  5 X 6 = 30  6 X 6 = 36
# 1 X 7 = 7  2 X 7 = 14  3 X 7 = 21  4 X 7 = 28  5 X 7 = 35  6 X 7 = 42  7 X 7 = 49
# 1 X 8 = 8  2 X 8 = 16  3 X 8 = 24  4 X 8 = 32  5 X 8 = 40  6 X 8 = 48  7 X 8 = 56  8 X 8 = 64
# 1 X 9 = 9  2 X 9 = 18  3 X 9 = 27  4 X 9 = 36  5 X 9 = 45  6 X 9 = 54  7 X 9 = 63  8 X 9 = 72  9 X 9 = 81

# %% [markdown]
# 到这里，我们的九九乘法表已经成功打印。
# 通过这个案例，小K借用毛爷爷一句话告诉你：“一切困难都是纸老虎”，学会拆解问题，找到突破口，就能KO问题。
# 最后，我们来总结一下这一关我们打通的任督二脉。
# ![思路](./picture/6-26.jpg)

# %% [markdown]
# ### 第一步:明确目标
# 现有一个列表，存放了小区邻居的工资收入，list=[10000,8500,9000,7000,8000,8000,9000,20000,15000,16000,5000] ，算一下小区邻居的平均工资收入。
# ### 第二步:分析过程
# 统计一下邻居的收入，算出平均值。
#
# ### 第三步:代码实现

# %%
list=[10000,8500,9000,7000,8000,8000,9000,20000,15000,16000,5000]
total = sum(list) 
print(total)
print(total / len(list))
# Out:
# 115500
# 10500.0
