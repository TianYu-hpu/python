# %% [markdown]
# 今天这节课，是我们第一个项目实战课。
# 正式上课之前，小K先带大家聊一聊项目实战课的目的。
# 在课程的准备过程中，我收到许多学员咨询的问题， 其中一个高频问题：
# ![实战](./picture/5-1.jpg)
# 古人云，“纸上得来终觉浅，绝知此事要躬行”，编程更是如此，要想编好程序，项目实战是成长最快的途径。我依稀记得当我第一次完成一个项目，有种“会当凌绝顶”的感觉，强大的成就感让自己彻夜激动。
# 小K非常希望屏幕前的你也能如此，早日感受编程技能给你带来的变化，并因这些变化让自己自信、成长。
# 项目的设置，主要带大家了解专业程序员一般是如何思考和解决问题的，再一遍遍分析问题、拆解问题及解决问题，在整个过程中充分理解所学知识。
# 在今天的课程中，我们会运用所学知识，也会适当补充一些新知识，一起完成一个文字版的「李逍遥大战拜月教主」。
# 好了，在开始工作之前，我们先谈谈一个项目一般是怎么完成的。更具体的说，程序员是如何思考解决问题的？
# 第一步，就是问题拆解。
# 问题拆解就是说，在面对一个问题时，将一个大问题拆解成多个步骤或者多个方面，逐步解决，最后完成整个问题，达到所要结果。
# 其实，这种拆解问题的思维很常见，你也遇到过。比如，你需要洗衣服，怎么完成洗衣服呢？
# 1.把衣服放进洗衣机；
# 2.倒入洗衣液；
# 3.然后点击开始按钮；
# 4.洗衣机洗衣服；
# 5.晾衣服。
# 但是，在编程中，我们拆解问题就需要按照编写代码的思维方式来拆解。
# For example, 在上一关作业练习中，葫芦娃和老爷爷猜数字问题，我们就可以进行拆解。
# ![项目分解](./picture/5-2.jpg)
# 江湖秘籍：完成一个项目的流程分三步：
# ![项目流程](./picture/5-3.jpg)
# 明确项目目的，指的就是我们希望这个程序干什么，达到什么样的效果，从而帮助我们分析整个项目流程，拆解项目；然而，一个完美的拆解方案，应当是按照从上往下的逻辑自然拆解，难度逐渐增加；逐步解决问题，逐渐完善整个项目功能。
# 那么接下来，我们正式进入项目实战，「李逍遥大战拜月教主」。
# 明确项目目的
# 在编程界，一般都是由产品经理提出项目需求，由程序员来实现。项目需求，大家可以简单的理解为项目效果。
# 这节课，小K扮演一下产品经理角色。我们此次要实现的是「李逍遥大战拜月教主」。具体效果参考下图：
# ![结果](./picture/5-4.gif)
# 用文字描述一下，在这个游戏中，李逍遥（freeLi）大战拜月教主(BOSS)，在这个游戏中，会随机生成李逍遥与拜月教主的属性，相互攻击，直到有一方的血量为0。
# 并且，这样的战斗采取三局两胜制，最后显示战斗结果，公布获胜方。
# ![结果](./picture/5-5.jpg)
# 分析流程，拆解项目
# 编写代码，谁都不能一步到位，尤其对于初入门的学员来说，逐步解决，逐渐完善才是最好的过程。
# 为了照顾大多数同学，我按照“难度递增，功能叠加”的思路，将这个游戏拆解成三个版本
# ![版本迭代](./picture/5-6.jpg)
# 版本1.0主要是帮我们理清战斗逻辑，而版本2.0与3.0会涉及到新的知识点，到时候再讲解。
# 当项目拆解后，剩下的就是逐步解决，逐渐完善了。
# ## 逐步解决，逐渐完善
# 下面，正式进入李逍遥大战拜月教主的战场。
# 首先来看版本1.0如何实现
# 理清战斗逻辑
# ![版本1.0](./picture/5-7.jpg)
# 首先，回想一下，李逍遥游戏中，都有哪些基础的元素？
# ![版本1.0](./picture/5-8.jpg)
# 根据这些元素，我们要做的主要有三步：
# 1、规定李逍遥和拜月教主的属性。
# 2、双方攻击时，失血量根据对方的攻击来计算。
# 3、如果有一方的血量减少到0以下，GAMEu3000OVER。
# 为了保持清晰思路，画出流程图如下
# ![版本1.0流程图](./picture/5-9.jpg)

# %% [markdown]
# 好，从第一步开始，设定【李逍遥】和【ＢＯＳＳ】的属性，及【血量】和【攻击力】。
# 代码片段
# ```
# print('【李逍遥】血量：100攻击力:25')   # 自定义李逍遥角色的血量和攻击
# print('【拜月教主】血量：100攻击力:20')   # 自定义拜月教主角色的血量和攻击
# ```
# 第二步，双方攻击人工计算各自剩余血量。
# 代码片段
# ```
# print('李逍遥发起了攻击，【拜月教主】剩余血量75') #人工计算拜月教主剩余血量100-25 = 75
# print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量80') #人工计算李逍遥剩余血量100-20 = 80
# ```
# 第三步，继续攻击，人工计算各自剩余血量。
# 代码片段
# ```
# print('李逍遥发起了攻击，【拜月教主】剩余血量50') #人工计算拜月教主剩余血量75-25 = 50
# print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量60') #人工计算李逍遥剩余血量80-20= 60
# ```
# 第四步，继续攻击，人工计算各自剩余血量。
# 代码片段
# ```
# print('李逍遥发起了攻击，【拜月教主】剩余血量25') #人工计算拜月教主剩余血量50-25= 25
# print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量40') #人工计算李逍遥剩余血量60-20=40
# ```
# 第五步，继续攻击，人工计算各自剩余血量。
# 代码片段
# ```
# print('李逍遥发起了攻击，【拜月教主】剩余血量0') #人工计算拜月教主剩余血量25-25=0，此时拜月教主血量为0，拜月教主死亡，游戏结束。
# print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量20') #人工计算李逍遥剩余血量40-20=20
# print('拜月教主死了,李逍遥赢了')
# ```
# 是不是so easy !我们现在要做的是，将三段代码拼接起来，形成一个完整的代码，然后再加一些分割线和格式修饰符，看起来更美观一些。
# 代码片段
# ```
# print('【李逍遥】血量：100攻击力:25')   # 自定义李逍遥角色的血量和攻击
# print('【拜月教主】血量：100攻击力:20')   # 自定义拜月教主角色的血量和攻击
# print('-----------------------')
# print('李逍遥发起了攻击，【拜月教主】剩余血量75') #人工计算拜月教主剩余血量100-25 = 75
# print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量80') #人工计算李逍遥剩余血量100-20 = 80
# print('-----------------------')
# print('李逍遥发起了攻击，【拜月教主】剩余血量50') #人工计算拜月教主剩余血量75-25 = 50
# print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量60') #人工计算李逍遥剩余血量80-20= 60
# print('-----------------------')
# print('李逍遥发起了攻击，【拜月教主】剩余血量25') #人工计算拜月教主剩余血量50-25= 25
# print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量40') #人工计算李逍遥剩余血量60-20=40
# print('-----------------------')
# print('李逍遥发起了攻击，【拜月教主】剩余血量0') #人工计算拜月教主剩余血量25-25=0，此时拜月教主血量为0，拜月教主死亡，游戏结束。
# print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量20') #人工计算李逍遥剩余血量40-20=20
# print('-----------------------')
# print('拜月教主死了,李逍遥赢了')
# ```
# 现在你运行一下下面代码，看看结果是不是符合你想要的？

# %%
print('【李逍遥】血量：100攻击力:25')   # 自定义李逍遥角色的血量和攻击
print('【拜月教主】血量：100攻击力:20')   # 自定义拜月教主角色的血量和攻击
print('-----------------------')

print('李逍遥发起了攻击，【拜月教主】剩余血量75') #人工计算拜月教主剩余血量100-25 = 75
print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量80') #人工计算李逍遥剩余血量100-20 = 80
print('-----------------------')

print('李逍遥发起了攻击，【拜月教主】剩余血量50') #人工计算拜月教主剩余血量75-25 = 50
print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量60') #人工计算李逍遥剩余血量80-20= 60
print('-----------------------')

print('李逍遥发起了攻击，【拜月教主】剩余血量25') #人工计算拜月教主剩余血量50-25= 25
print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量40') #人工计算李逍遥剩余血量60-20=40
print('-----------------------')

print('李逍遥发起了攻击，【拜月教主】剩余血量0') #人工计算拜月教主剩余血量25-25=0，此时拜月教主血量为0，拜月教主死亡，游戏结束。
print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量20') #人工计算李逍遥剩余血量40-20=20
print('-----------------------')

print('拜月教主死了,李逍遥赢了')
# Out:
# 【李逍遥】血量：100攻击力:25
# 【拜月教主】血量：100攻击力:20
# -----------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量75
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量80
# -----------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量50
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量60
# -----------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量25
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量40
# -----------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量0
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量20
# -----------------------
# 拜月教主死了,李逍遥赢了

# %% [markdown]
# 看起来有意思了吧？不过这一下子就全部打印出来所有结果了，这也太快了，体验不出游戏的快感啊。
# 为了，让我们看着结果有进程性，让打印的内容间隔出现，我们引入一个类似“延迟时间”的东西。再Python江湖里，我们需要用到两行代码。
# ![延时](./picture/5-10.jpg)
# 这里有个新名词，叫做time模块，先不要想着研究透它，先使用，混个脸熟，再去详解。后期章节会着重介绍它。
# time.sleep()就是制作延迟效果的，让代码能够延迟出现，那我们就让代码延迟2s出现。代码改写成下面样子。

# %%
import time #调用time模块

print('【李逍遥】血量：100攻击力:25')   # 自定义李逍遥角色的血量和攻击
print('【拜月教主】血量：100攻击力:20')   # 自定义拜月教主角色的血量和攻击
print('-----------------------')
time.sleep(2)

print('李逍遥发起了攻击，【拜月教主】剩余血量75') #人工计算拜月教主剩余血量100-25 = 75
print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量80') #人工计算李逍遥剩余血量100-20 = 80
print('-----------------------')
time.sleep(2)

print('李逍遥发起了攻击，【拜月教主】剩余血量50') #人工计算拜月教主剩余血量75-25 = 50
print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量60') #人工计算李逍遥剩余血量80-20= 60
print('-----------------------')
time.sleep(2)

print('李逍遥发起了攻击，【拜月教主】剩余血量25') #人工计算拜月教主剩余血量50-25= 25
print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量40') #人工计算李逍遥剩余血量60-20=40
print('-----------------------')
time.sleep(2)

print('李逍遥发起了攻击，【拜月教主】剩余血量0') #人工计算拜月教主剩余血量25-25=0，此时拜月教主血量为0，拜月教主死亡，游戏结束。
print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量20') #人工计算李逍遥剩余血量40-20=20
print('-----------------------')
time.sleep(2)

print('拜月教主死了,李逍遥赢了')
# Out:
# 【李逍遥】血量：100攻击力:25
# 【拜月教主】血量：100攻击力:20
# -----------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量75
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量80
# -----------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量50
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量60
# -----------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量25
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量40
# -----------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量0
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量20
# -----------------------
# 拜月教主死了,李逍遥赢了

# %% [markdown]
# 呼呼呼呼看起来不错，总算完成了项目版本1.0。
# 但是你有没有感觉，现在代码有些low。都是print()函数啊， 并且还要手动计算剩余血量。
# 那就改造一下呗。
# 接下来改造两个方面：
# 1、李逍遥和拜月教主的属性（血量与攻击力）让计算机随机指定。
# 2、战斗过程中血量变化让计算机来计算。
# 好了，下面进入版本2.0，开始解决上面出现问题。
# ## 随机属性，自动PK
#
# ![2.0](./picture/5-11.jpg)
# 如上面所述，这个阶段，我们主要增加【随机属性】和【自动战斗】两个功能，画出流程图：
# ![2.0流程图](./picture/5-12.jpg)
# 想一想：版本1.0中，我们自定义双方属性，这不等于暗箱操作吗。所以，为了公平起见，我们要让计算机随机生成双方属性。
# 选择题
# 现在问题来了，要生成随机属性，也就是生成随机数字，怎么办？
# A：小K教我。
# B：去群里，讨论。
# C：自己查，上网找资料。
# 哈哈，授人以鱼不如授人以渔，我们要养成独立思考的习惯。
# 遇到问题，问问度娘吗？看看度娘怎么说？
# ![baidu](./picture/5-13.jpg)
# ![baidu](./picture/5-14.jpg)
# 看到教程中，要生成随机数，要使用random随机数模块中的randint（a，b）函数，括号内为a,b两个数字为生成随机数的范围，a是小数字，b是大数字。
# 运行一下下面代码，观察终端里的效果。

# %%
#多运行几次，看看结果是不是随机生成的~
import random 
#调用random模块
num = random.randint(1,100)
# 随机生成1-100范围内（含1和100）的一个整数，并赋值给变量a
print(num)
# Out:
# 72

# %% [markdown]
# 好，既然随机数搞定，那么下面我们能就把随机数引入到项目中。
# 请听题：
# 1、定义两个变量，用来存储李逍遥的血量和攻击力。
# 2、血量是100-150之间的随机数，攻击力是20-30之间的随机数。
# 3、打印两个变量

# %%
import random
freeLi_life = random.randint(100,150)
#表示李逍遥血量
freeLi_attack = random.randint(20,30)
#表示李逍遥攻击
print(freeLi_life)
print(freeLi_attack)
# Out:
# 126
# 20

# %% [markdown]
# 因该没啥问题吧?可能大家对这个变量名字会感到困惑。
# 江湖秘籍：变量命名应使用英文来表达，如果是多个单词，单词与单词之间需要使用英文下划线_来分隔。
# 好了，我们已经能够随机生成李逍遥的血量和攻击力了，下面我们要生成拜月教主的血量和攻击力，完成随机生成两者属性的任务

# %%
import time
import random
#也可合并写成一行：import time,random

# 生成随机属性
freeLi_life = random.randint(100,150) # “freeLi_life” 代表李逍遥血量
freeLi_attack = random.randint(20,30) # “freeLi_attack” 代表李逍遥攻击
BOSS_life = random.randint(100,150) # “BOSS_life” 代表拜月教主血量
BOSS_attack = random.randint(20,30) # “BOSS_attack” 代表拜月教主攻击

# 展示双方角色的属性
print('【李逍遥】\n'+'血量：'+str(freeLi_life)+'\n攻击：'+str(freeLi_attack))
#freeLi_life和freeLi_attack的数据类型都是整数，所以拼接时需要先用str()转换
print('------------------------')
time.sleep(1)
#暂停一秒再执行后续代码
print('【拜月教主】\n'+'血量：'+str(BOSS_life)+'\n攻击：'+str(BOSS_attack))
print('------------------------')
# Out:
# 【李逍遥】
# 血量：135
# 攻击：20
# ------------------------
# 【拜月教主】
# 血量：112
# 攻击：20
# ------------------------

# %% [markdown]
# 截至目前，我们已经解决了随机生成属性的问题，接下来，我们就来实现“自动PK”
# ![2.0流程图](./picture/5-15.jpg)
# 现在是李逍遥和拜月教主双方互相攻击，到底要打斗多少次，我们不知道，打斗多长时间我们也不知道，我们只知道，有一个的血量为0时，战斗结束。也就是我们只知道循环的条件。
# OK。如何让这个循环一直执行，也就是双方的血量都大于0嘛。
# ![条件](./picture/5-16.jpg)
# while循环中要同时满足两个条件，即两个条件都为真，所以我们用and来连接，用代码表示：
# 代码片段
# ```
# while(freeLi_life>0) and (BOSS_life>0) #and两边用（）括起来，更方便大家阅读。
# ```
# 条件找到了，接下来就是while的循环体，双方互相攻击：
#
# 代码片段
# ```
# print('李逍遥发起了攻击，【拜月教主】剩余血量XXX')
# print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量XXX')
# ```
# 其中【拜月教主】剩余血量=拜月教主当前血量-李逍遥攻击力，【李逍遥】剩余血量=李逍遥当前血量-拜月教主攻击力
# 我们在前面已经定义好了这四个变量，每一次攻击后， freeLi_life（李逍遥血量）与BOSS_life（拜月教主血量）都会重新赋值，代码就是：
# 代码片段
# ```
# freeLi_life = freeLi_life - BOSS_attack
# BOSS_life = BOSS_life - freeLi_attack
# #赋值语句的执行顺序是先计算等号右边，再赋值给左边的变量
# ```
# OK，自动PK的基础代码已经完成，我们先合并一下这些代码：

# %%
import time
import random
#也可合并写成一行：import time,random

# 生成随机属性
freeLi_life = random.randint(100,150) # “freeLi_life” 代表李逍遥血量
freeLi_attack = random.randint(20,30) # “freeLi_attack” 代表李逍遥攻击
BOSS_life = random.randint(100,150) # “BOSS_life” 代表拜月教主血量
BOSS_attack = random.randint(20,30) # “BOSS_attack” 代表拜月教主攻击

# 展示双方角色的属性
print('【李逍遥】\n'+'血量：'+str(freeLi_life)+'\n攻击：'+str(freeLi_attack))
#freeLi_life和freeLi_attack的数据类型都是整数，所以拼接时需要先用str()转换
print('------------------------')
time.sleep(1)
#暂停一秒再执行后续代码
print('【拜月教主】\n'+'血量：'+str(BOSS_life)+'\n攻击：'+str(BOSS_attack))
print('------------------------')

# 自动PK阶段
while(freeLi_life>0) and (BOSS_life>0):
    freeLi_life = freeLi_life - BOSS_attack 
    BOSS_life = BOSS_life - freeLi_attack
# Out:
# 【李逍遥】
# 血量：107
# 攻击：28
# ------------------------
# 【拜月教主】
# 血量：115
# 攻击：30
# ------------------------

# %% [markdown]
# 好了，写到这里，就只剩下补完while循环中的内容，也就是实时打印李逍遥与拜月教主的剩余血量。
# 代码片段
# ```
# print('李逍遥发起了攻击，【拜月教主】剩余血量XXX')
# print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量XXX')
# ```
# 在上面我们已经计算出了李逍遥和拜月教主的剩余血量，那我们就用变量来替代XXX字符，完成整个代码。

# %%
import time
import random
#也可合并写成一行：import time,random

# 生成随机属性
freeLi_life = random.randint(100,150) # “freeLi_life” 代表李逍遥血量
freeLi_attack = random.randint(20,30) # “freeLi_attack” 代表李逍遥攻击
BOSS_life = random.randint(100,150) # “BOSS_life” 代表拜月教主血量
BOSS_attack = random.randint(20,30) # “BOSS_attack” 代表拜月教主攻击

# 展示双方角色的属性
print('【李逍遥】\n'+'血量：'+str(freeLi_life)+'\n攻击：'+str(freeLi_attack))
#freeLi_life和freeLi_attack的数据类型都是整数，所以拼接时需要先用str()转换
print('------------------------')
time.sleep(1)
#暂停一秒再执行后续代码
print('【拜月教主】\n'+'血量：'+str(BOSS_life)+'\n攻击：'+str(BOSS_attack))
print('------------------------')

# 自动PK阶段
while(freeLi_life>0) and (BOSS_life>0):
    freeLi_life = freeLi_life - BOSS_attack 
    BOSS_life = BOSS_life - freeLi_attack 

    print('李逍遥发起了攻击，【拜月教主】剩余血量'+str(BOSS_life))
    #freeLi_life是整数，所以拼接时要先用str()转换
    print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量'+str(freeLi_life))
    print('------------------------')
    time.sleep(2)
# 为了体现出战斗回合，这里停顿2秒
# Out:
# 【李逍遥】
# 血量：109
# 攻击：21
# ------------------------
# 【拜月教主】
# 血量：109
# 攻击：25
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量88
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量84
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量67
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量59
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量46
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量34
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量25
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量9
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量4
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量-16
# ------------------------

# %% [markdown]
# 不过它还没有全部解决：打印出每局结果，三局两胜打印最终战果。这就是版本3.0需要做的事情。
# 加油，继续冲刺吧。
# 打印战果，三局两胜。
# ![3.0](./picture/5-17.jpg)
# 对比2.0版本，在3.0版本中，我们想要增加的功能是：1、打印战果：每局战斗后，根据胜负平的结果打印出不同的提示。2、三局两胜：双方战斗三局，胜局多的为最终赢家。
# ![3.0](./picture/5-18.jpg)
# 回来看项目，当李逍遥与拜月教主PK的时候，血量都会开始递减，经过多次攻击，会出现如下结果。
# ![3.0](./picture/5-19.jpg)
# ![3.0](./picture/5-20.jpg)
# ![3.0](./picture/5-21.jpg)
# ![3.0](./picture/5-22.jpg)
# ![3.0](./picture/5-23.jpg)
# ![3.0](./picture/5-24.jpg)
# ![3.0](./picture/5-25.jpg)

# %%
import time
import random
#也可合并写成一行：import time,random
freeLi_score = 0
#存放李逍遥赢的局数。
BOSS_score = 0
#存放拜月教主赢的局数
for i in range(1,10):
    time.sleep(1)  # 让局与局之间有较明显的有时间间隔
    print(' \n——————现在进行第'+str(i)+'局，3，2，1，go!——————')  # 作为局的标记

    # 生成随机属性
    freeLi_life = random.randint(100,150) # “freeLi_life” 代表李逍遥血量
    freeLi_attack = random.randint(20,30) # “freeLi_attack” 代表李逍遥攻击
    BOSS_life = random.randint(100,150) # “BOSS_life” 代表拜月教主血量
    BOSS_attack = random.randint(20,30) # “BOSS_attack” 代表拜月教主攻击

    # 展示双方角色的属性
    print('【李逍遥】\n'+'血量：'+str(freeLi_life)+'\n攻击：'+str(freeLi_attack))
    #freeLi_life和freeLi_attack的数据类型都是整数，所以拼接时需要先用str()转换
    print('------------------------')
    time.sleep(1)
    #暂停一秒再执行后续代码
    print('【拜月教主】\n'+'血量：'+str(BOSS_life)+'\n攻击：'+str(BOSS_attack))
    print('------------------------')

    # 自动PK阶段
    while(freeLi_life>0) and (BOSS_life>0):
        freeLi_life = freeLi_life - BOSS_attack 
        BOSS_life = BOSS_life - freeLi_attack 

        print('李逍遥发起了攻击，【拜月教主】剩余血量'+str(BOSS_life))
        #freeLi_life是整数，所以拼接时要先用str()转换
        print('拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量'+str(freeLi_life))
        print('------------------------')
        time.sleep(2)
        # 为了体现出战斗回合，这里停顿2秒  

    # 打印战果
    if freeLi_life > 0 and BOSS_life <= 0:
        freeLi_score=freeLi_score+1
        print('拜月教主挂了，李逍遥赢了')
    elif freeLi_life <= 0 and BOSS_life > 0:
        BOSS_score = BOSS_score +1
        print('悲催，拜月教主把李逍遥干掉了！')
    else:
        print('哎呀，李逍遥和拜月教主同归于尽了！')

    if freeLi_score > BOSS_score  :
        time.sleep(1)
        print('【 大战3个回合：李逍遥赢了！】')
    elif BOSS_score  > freeLi_score:
        print('【大战3个回合：李逍遥输了！】')
    else: 
        print('【大战3个回合：平局！】')
    
    if i >= 3:    
        choose=input('你敢与我再次决战吗？？回答:再战/结束')
        if choose=='结束':
            print("该怂还是得怂")
            break
        else:
            print("男人不能说自己不行，生死看淡，我要往死里干")
# Out:
#
# ——————现在进行第1局，3，2，1，go!——————
# 【李逍遥】
# 血量：146
# 攻击：20
# ------------------------
# 【拜月教主】
# 血量：147
# 攻击：30
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量127
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量116
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量107
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量86
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量87
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量56
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量67
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量26
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量47
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量-4
# ------------------------
# 悲催，拜月教主把李逍遥干掉了！
# 【大战3个回合：李逍遥输了！】
#
# ——————现在进行第2局，3，2，1，go!——————
# 【李逍遥】
# 血量：125
# 攻击：21
# ------------------------
# 【拜月教主】
# 血量：112
# 攻击：22
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量91
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量103
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量70
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量81
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量49
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量59
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量28
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量37
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量7
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量15
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量-14
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量-7
# ------------------------
# 哎呀，李逍遥和拜月教主同归于尽了！
# 【大战3个回合：李逍遥输了！】
#
# ——————现在进行第3局，3，2，1，go!——————
# 【李逍遥】
# 血量：147
# 攻击：29
# ------------------------
# 【拜月教主】
# 血量：136
# 攻击：30
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量107
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量117
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量78
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量87
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量49
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量57
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量20
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量27
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量-9
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量-3
# ------------------------
# 哎呀，李逍遥和拜月教主同归于尽了！
# 【大战3个回合：李逍遥输了！】
# 你敢与我再次决战吗？？回答:再战/结束再战
# 不是个男人，男人不能说自己不行，生死看淡，我要往死里干
#
# ——————现在进行第4局，3，2，1，go!——————
# 【李逍遥】
# 血量：145
# 攻击：23
# ------------------------
# 【拜月教主】
# 血量：135
# 攻击：28
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量112
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量117
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量89
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量89
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量66
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量61
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量43
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量33
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量20
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量5
# ------------------------
# 李逍遥发起了攻击，【拜月教主】剩余血量-3
# 拜月教主向李逍遥发起了攻击，【李逍遥】剩余血量-23
# ------------------------
# 哎呀，李逍遥和拜月教主同归于尽了！
# 【大战3个回合：李逍遥输了！】
# 你敢与我再次决战吗？？回答:再战/结束结束
# 该怂还是得怂

# %%
for i in range(1,101):
    if i%7==0:
        print('这个数是7的倍数%d' %i)
