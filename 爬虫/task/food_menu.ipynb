# %%
import requests
from bs4 import BeautifulSoup

headers={'user-agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'}

res_foods = requests.get('http://www.xiachufang.com/explore/',headers=headers)
bs_foods = BeautifulSoup(res_foods.text,'html.parser')

tag_name = bs_foods.find_all('p',class_='name')
tag_ingredients = bs_foods.find_all('p',class_='ing ellipsis')
list_all = []
for x in range(len(tag_name)):
    list_food = [tag_name[x].text[18:-14],tag_name[x].find('a')['href'],tag_ingredients[x].text[1:-1]]
    list_all.append(list_food)
print(list_all)
# Out:
# [['夏天多吃这道菜，清热解暑，酸酸甜甜开胃下饭，糖醋茄子\n', '/recipe/104656009/', '茄子、蒜瓣、香葱、玉米油、玉米淀粉、糖醋汁：冠利香醋、糖醋汁：生抽、糖醋汁：老抽、糖醋汁：蚝油、糖醋汁：番茄酱、糖醋汁：白糖、糖醋汁：盐、糖醋汁：玉米淀粉、糖醋汁：水'], ['鲜到赛海鲜，香到掀屋顶\n', '/recipe/104668369/', '蚕豆、火腿、橄榄油'], ['港式珍珠奶茶\n', '/recipe/104660049/', '水、锡兰红茶、白砂糖、牛奶、港版黑白全脂淡奶、淡奶油、炼奶、自制珍珠（我另一个作品菜谱里面有教）'], ['黑芝麻糕\n', '/recipe/104653791/', '黑芝麻粉、糯米粉、粘米粉、细砂糖、玉米油、水'], ['免翻拌～无需蛋黄的芒果酸奶冰激凌\n', '/recipe/104629466/', '芒果、酸奶、淡奶油、糖、蔓越莓干'], ['减肥蔬菜三明治\n', '/recipe/104668384/', '西红柿、鸡蛋、生菜、香菜、黄瓜、鸡胸肉。牛肉等、如果想减肥 尽量用的食材是低热量 高蛋白的'], ['【老上海红烧肉】我又对红烧肉有了新的认识\n', '/recipe/104667406/', '五花肉、老姜、黄酒、生抽、老抽、冰糖、盐'], ['🔥简单好吃的土豆饼\n', '/recipe/104657676/', '土豆、火腿肠、胡萝卜、面粉'], ['好吃好做的早餐鸡蛋卷\n', '/recipe/104190840/', '鸡蛋、香肠或者各种肉或者虾、盐、葱花、蔬菜、淀粉'], ['一整天不塌，超稳定奶油霜！\n', '/recipe/104660002/', '方法一—————————、淡奶油、太古糖霜、可可粉、柠檬汁、方法二—————————、淡奶油、白砂糖、吉利丁片、温水'], ['芒果雪糕（非常简单）\n', '/recipe/104631217/', '芒果（去皮后）、细砂糖、淡奶油、纯牛奶'], ['无敌开胃的•酸辣汤\n', '/recipe/104405483/', '西红柿、嫩豆腐、香菇、肉丝（火腿或猪肝）、木耳、金针菇、鸡蛋、香菜（小葱）、水淀粉、盐、鸡精、辣椒面（辣椒沫）、老抽、生抽、白胡椒粉、陈醋'], ['马路边杀手！香辣过瘾的孜然火腿土豆丁！\n', '/recipe/104634799/', '土豆、火腿肠、葱花'], ['巨好吃㊙️酸辣凉拌面❗️十分钟搞定，简单快手❗️\n', '/recipe/104347814/', '面条、葱花、蒜末、黄瓜、香菜末、熟花生米'], ['蛋糕卷这样做‼️不掉皮不开裂（小视频食谱）\n', '/recipe/104653998/', '原味蛋糕卷、鸡蛋、牛奶或水、油、细砂糖、低粉、可可蛋糕卷、鸡蛋、牛奶或水、油、细砂糖、可可粉、低粉'], ['家常丝瓜炒鸡蛋做法，简单的快手菜，鲜嫩可口\n', '/recipe/104657486/', '丝瓜、鸡蛋、大蒜、蚝油、生抽、食用盐'], ['0失败，超简单水果果冻蛋糕！\n', '/recipe/104591766/', '牛奶、白糖、白凉粉、芒果、清水、葡萄、蓝莓'], ['超详细简单泡芙\n', '/recipe/104668121/', '鸡蛋、水、黄油、细砂糖（面糊）、盐、华丽分割线————————-、淡奶油、细砂糖（奶油）'], ['满满少女心的粉红珍珠\n', '/recipe/104612526/', '苋菜汁、木薯粉、白砂糖'], ['一次就成功的腌糖蒜\n', '/recipe/104650660/', '新大蒜、米醋、白醋、冰糖、绵白糖、食盐、白酒'], ['超快速软绵绵奶香吐司\n', '/recipe/104359837/', '高筋面粉（王后吐司粉）、奶粉、细砂糖、盐、酵母、鸡蛋、牛奶、淡奶油、炼奶、黄油、450G吐司盒子'], ['妇科圣药调经养血的玫瑰四物膏（遵循古法三煎三煮）\n', '/recipe/104668160/', '川芎、当归、白芍、熟地、红枣、黑糖、麦芽糖、干玫瑰花、蜂蜜'], ['红烧狮子头\n', '/recipe/104668374/', '猪肉碎、山药、淀粉、白糖、海盐、鸡蛋、料酒、葱、姜、白胡椒'], ['一次成功的香蕉派\n', '/recipe/104668218/', '鸡蛋、香蕉、手抓饼、马苏里拉芝士碎'], ['凉拌黑木耳\n', '/recipe/104650322/', '木耳、蒜、西芹、酱油、香醋、麻油、糖、盐、小米椒、香菜、姜、胡萝卜、鲜百合']]
